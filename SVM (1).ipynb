# %% [markdown]
# # Task 1: Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Data Science Asignments datasets\mushroom.csv")
df
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1995         863    sunken       scaly     brown     yes     foul
# 1996        1160    sunken       scaly    purple     yes    musty
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
# 1999        1073    convex       scaly    yellow     yes  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# cap_shape                   0
# cap_surface                 0
# cap_color                   0
# bruises                     0
# odor                        0
# gill_attachment             0
# gill_spacing                0
# gill_size                   0
# gill_color                  0
# stalk_shape                 0
# stalk_root                  0
# stalk_surface_above_ring    0
# stalk_surface_below_ring    0
# stalk_color_above_ring      0
# stalk_color_below_ring      0
# veil_type                   0
# veil_color                  0
# ring_number                 0
# ring_type                   0
# spore_print_color           0
# population                  0
# habitat                     0
# class                       0
# stalk_height                0
# cap_diameter                0
# dtype: int64

# %%
print(df.describe())
# Out:
#         Unnamed: 0  stalk_height  cap_diameter
# count  2000.000000   2000.000000   2000.000000
# mean    624.974000      8.449118     12.314345
# std     375.091938      3.697217      7.048845
# min       0.000000      2.000000      1.000000
# 25%     290.000000      5.291009      5.723521
# 50%     607.000000      8.318596     12.124902
# 75%     957.250000     11.781272     18.698605
# max    1279.000000     15.095066     25.000054

# %%
df["Unnamed: 0"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Unnamed: 0"].plot(kind="box")
# Out:
# <Axes: >

# %%
df["stalk_height"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["stalk_height"].plot(kind="box")
# Out:
# <Axes: >

# %%
df["cap_diameter"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["cap_diameter"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# # Task 2: Data Preprocessing

# %%
df_num1 = df.iloc[:,0:1]
df_num2 = df.iloc[:,24:]
df_num = pd.concat([df_num1,df_num2],axis=1)
df_num
# Out:
#       Unnamed: 0  stalk_height  cap_diameter
# 0           1167     14.276173      5.054983
# 1           1037      3.952715     19.068319
# 2            309      9.054265      7.205884
# 3            282      5.226499     20.932692
# 4            820     14.037532     12.545245
# ...          ...           ...           ...
# 1995         863      5.877891     17.464145
# 1996        1160      6.500840     13.501957
# 1997         265     13.558064     11.270020
# 1998         411     11.092703      8.423199
# 1999        1073     13.066414     21.056642
#
# [2000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
SS_num = SS.fit_transform(df_num)
SS_num = pd.DataFrame(SS_num)
SS_num.columns = list(df_num)
SS_num
# Out:
#       Unnamed: 0  stalk_height  cap_diameter
# 0       1.445410      1.576459     -1.030123
# 1       1.098741     -1.216463      0.958407
# 2      -0.842601      0.163717     -0.724904
# 3      -0.914602     -0.871852      1.222967
# 4       0.520072      1.511897      0.032765
# ...          ...           ...           ...
# 1995    0.634739     -0.695623      0.730771
# 1996    1.426743     -0.527090      0.168525
# 1997   -0.959935      1.382181     -0.148193
# 1998   -0.570600      0.715199     -0.552164
# 1999    1.194742      1.249170      1.240556
#
# [2000 rows x 3 columns]

# %%
df_cat = df.select_dtypes(include=['object', 'category'])

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
LE_cat = df_cat.apply(LE.fit_transform)
LE_cat = pd.DataFrame(LE_cat)
LE_cat.columns = list(df_cat)
LE_cat
# Out:
#       cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0             4            2          7        0     1                1
# 1             4            0          6        0     1                3
# 2             3            1          5        1     4                1
# 3             0            2          4        1     3                3
# 4             3            3          8        1     5                2
# ...         ...          ...        ...      ...   ...              ...
# 1995          4            2          0        1     4                0
# 1996          4            2          5        1     5                0
# 1997          2            1          3        1     3                3
# 1998          0            3          7        0     7                2
# 1999          2            2          8        1     7                1
#
#       gill_spacing  gill_size  gill_color  stalk_shape  ...  \
# ...

# %%
df_new = pd.concat([SS_num,LE_cat],axis=1)
df_new
# Out:
#       Unnamed: 0  stalk_height  cap_diameter  cap_shape  cap_surface  \
# 0       1.445410      1.576459     -1.030123          4            2
# 1       1.098741     -1.216463      0.958407          4            0
# 2      -0.842601      0.163717     -0.724904          3            1
# 3      -0.914602     -0.871852      1.222967          0            2
# 4       0.520072      1.511897      0.032765          3            3
# ...          ...           ...           ...        ...          ...
# 1995    0.634739     -0.695623      0.730771          4            2
# 1996    1.426743     -0.527090      0.168525          4            2
# 1997   -0.959935      1.382181     -0.148193          2            1
# 1998   -0.570600      0.715199     -0.552164          0            3
# 1999    1.194742      1.249170      1.240556          2            2
#
#       cap_color  bruises  odor  gill_attachment  gill_spacing  ...  \
# 0             7        0     1                1             2  ...
# ...

# %%
X = df_new.drop(["class"],axis=1)
Y = df_new["class"]

# %%
from sklearn.decomposition import PCA
pca = PCA()
pc_X = pca.fit_transform(X)
pc_X = pd.DataFrame(pc_X)
pc_X
# Out:
#             0         1         2         3         4         5         6   \
# 0     2.240716  1.557938  5.425142 -0.696237  0.487417 -1.097634  2.456248
# 1    -2.616948 -0.495982  0.176461 -5.727014  2.336431 -2.477872  1.972832
# 2     3.402626  3.098099 -2.764374  1.072512  1.067383 -1.065510  1.316458
# 3     1.017738  2.299380 -0.648678  2.122291 -1.704093 -2.596639 -2.342072
# 4     1.258549  4.237941  2.930478  1.042284  1.501367  3.566009 -0.316970
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -2.250538  0.118997 -2.493356  1.535892 -3.508305  1.268611  0.193717
# 1996  4.346498  2.517981 -1.483535  0.619274  1.286761  2.595709  2.110915
# 1997  1.463316  0.529267  2.207608 -1.626306 -3.381181  4.826628 -2.069863
# 1998 -0.013498 -1.534091  2.691292  0.729374  2.710091 -1.014223 -5.468007
# 1999  2.185476  2.466399 -2.413949 -1.989026  4.627358  3.182837 -2.939773
#
# ...

# %%
X_pc = pc_X.iloc[:,0:5]
Y = df_new["class"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_pc,Y,test_size=0.2)

# %% [markdown]
# # Task 3: Data Visualization

# %%
#construct a scatter plot in between X1 and X2 and Y variable with 2D visualization
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
plt.scatter(pc_X.iloc[:,0:1],pc_X.iloc[:,1:2],c=Y, cmap='viridis')
plt.xlabel("X1")
plt.ylabel("X2")
plt.title("Scatter Plot of X1 vs X2")
plt.colorbar(label="Y")
plt.show()

# %%
import matplotlib.pyplot as plt
counts = df["class"].value_counts()
colors = ["blue","orange"]
plt.bar(counts.index, counts.values,color=colors)
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Class Distribution")
plt.show()

# %% [markdown]
# # Task 4: SVM Implementation

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf',gamma=0.5)
model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
print("Accuracy Score :",accuracy_score(Y_test,Y_pred_test))
print("Precision Score :",precision_score(Y_test,Y_pred_test))
print("Recall Score :",recall_score(Y_test,Y_pred_test))
print("F1_score Score :",f1_score(Y_test,Y_pred_test))
# Out:
# Accuracy Score : 0.8475
# Precision Score : 0.8413173652694611
# Recall Score : 0.972318339100346
# F1_score Score : 0.9020866773675762

# %% [markdown]
# # Task 5: Visualization of SVM Results

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
plt.scatter(X_test.iloc[:,0:1],X_test.iloc[:,1:2],c=X_test.iloc[:,0:1], cmap='viridis')  # Use Y for color mapping
plt.xlabel("X_test")
plt.ylabel("X_test")
plt.title("Scatter Plot of X_test vs X_p")
plt.colorbar(label="Y_test")
plt.show()

# %%
# construct a scatter plot in between X1 and X2 and Y variable with 3 D visualization
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_test.iloc[:, 0],X_test.iloc[:,1],Y_test,c=Y_test,cmap='viridis')
ax.set_xlabel('X_test')
ax.set_ylabel('X_test')
ax.set_zlabel('Y_test')
ax.set_title('3D Scatter Plot')
plt.show()

# %% [markdown]
# # Task 6: Parameter Tuning and Optimization And Task 7: Comparison and Analysis

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.svm import SVC

# %%
param_grid = {
    "kernel" : ["linear"],
    "degree" : list(range(1, 8)),
    "C" : list(range(1,8,2)),
}

# %%
grid_search = GridSearchCV(SVC(),param_grid,cv=10,scoring='accuracy')
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [1, 3, 5, 7], 'degree': [1, 2, 3, 4, 5, 6, 7],
#                          'kernel': ['linear']},
#              scoring='accuracy')

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'C': 1, 'degree': 1, 'kernel': 'linear'}
# Best score: 0.694375

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear',C=1)
model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test = model.predict(X_test)

# %%
print("Accuracy Score :",accuracy_score(Y_test,Y_pred_test))
print("Precision Score :",precision_score(Y_test,Y_pred_test))
print("Recall Score :",recall_score(Y_test,Y_pred_test))
print("F1_score Score :",f1_score(Y_test,Y_pred_test))
# Out:
# Accuracy Score : 0.7225
# Precision Score : 0.7225
# Recall Score : 1.0
# F1_score Score : 0.8388969521044993

# %%
param_grid = {
    "kernel" : ["poly"],
    "degree" : list(range(1, 8)),
}

# %%
grid_search = GridSearchCV(SVC(),param_grid,cv=10,scoring='accuracy')
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'degree': [1, 2, 3, 4, 5, 6, 7], 'kernel': ['poly']},
#              scoring='accuracy')

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'degree': 7, 'kernel': 'poly'}
# Best score: 0.739375

# %%
from sklearn.svm import SVC
model = SVC(kernel='poly',degree=7)
model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test = model.predict(X_test)

# %%
print("Accuracy Score :",accuracy_score(Y_test,Y_pred_test))
print("Precision Score :",precision_score(Y_test,Y_pred_test))
print("Recall Score :",recall_score(Y_test,Y_pred_test))
print("F1_score Score :",f1_score(Y_test,Y_pred_test))
# Out:
# Accuracy Score : 0.75
# Precision Score : 0.7506631299734748
# Recall Score : 0.9792387543252595
# F1_score Score : 0.8498498498498499

# %%
param_grid = {
    "kernel" : ["rbf"],
    "gamma" : np.arange(0.1,1,0.1).tolist()
}

# %%
grid_search = GridSearchCV(SVC(),param_grid,cv=10,scoring='accuracy')
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'gamma': [0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6,
#                                    0.7000000000000001, 0.8, 0.9],
#                          'kernel': ['rbf']},
#              scoring='accuracy')

# %%
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
# Out:
# Best parameters: {'gamma': 0.8, 'kernel': 'rbf'}
# Best score: 0.86875

# %%
from sklearn.svm import SVC
model = SVC(kernel='rbf',gamma=0.8)
model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test = model.predict(X_test)

# %%
print("Accuracy Score :",accuracy_score(Y_test,Y_pred_test))
print("Precision Score :",precision_score(Y_test,Y_pred_test))
print("Recall Score :",recall_score(Y_test,Y_pred_test))
print("F1_score Score :",f1_score(Y_test,Y_pred_test))
# Out:
# Accuracy Score : 0.8625
# Precision Score : 0.8461538461538461
# Recall Score : 0.9896193771626297
# F1_score Score : 0.9122807017543859

# %% [markdown]
# ### Analyze SVM strengths and weaknesses for the Mushroom dataset based on EDA and visualization results.
# Srengths : Good Accuracy,effective with non-linear data and high recall value.
# Weakness : Low precision and overfitting

# %% [markdown]
# ### Discuss practical implications of SVM in real-world classification tasks.
# Spam Detection,Object Detection,Credit score,Consumer segmentation and all classification as well as regression tasks.
